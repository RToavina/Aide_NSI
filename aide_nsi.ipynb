# %% [markdown]
# Ce fichier a pour but d'apporter des éléments de corrections aux exercices que vous avez du mal à comprendre. Relisez les énoncés, testez toutes les possibilités et de revoyez tous les angles d'approches pour trouver une solution au problème. Et si vraiment vous êtes bloqués, lisez le corrigé, essayez de le comprendre avant de le reprendre dans vos codes. Je compte sur votre maturité pour ne pas juste reprendre le code sans le comprendre.
